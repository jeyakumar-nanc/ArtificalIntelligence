# %% [markdown]
# <a href="https://colab.research.google.com/github/jeyakumar-nanc/ArtificalIntelligence/blob/main/ReverseSearchImage_Engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.	Image Search Engine Baseline:**
#
# •Image search Engine gives similar images of given image. We use content-based image retrieval concept to build image search engine.
#
# •Content-based image retrieval (CBIR) is a system for retrieving relevant images based on a given image. The system consists of an image query and an image database. It works as below
#
# •	Extract features on all images and query image
#
# •	System will calculate similarities between the query with all images on the database.
#
# •	System will retrieve all the images that have a great similarity with the query

# %% [markdown]
# **Search Engine Baseline Model Implementation:**
#
# •	Download the dataset: The images dataset is downloaded from LFW Face Database : Main (umass.edu).
#
# Note: Since the dataset is huge and taking long computation time. We used subset (1508 images from this set
#
# •	We use convolutional neural network (CNN) for extracting images features for baseline model
#
# •	Insert the query image ( we select image randomly) and extract its features using CNN
#
# •	Calculate the similarities of query image with all images using KNN algorithm. This algorithm calculates distances (Euclidean Distance) between query image features with all images features
#
# •	Retrieve the most similar result:  we get k images that has smaller distances to query image to get similar images.

# %% [markdown]
# **Image search Engine baseline model implementation using python (using google colab):**
#
# •	Uploaded images dataset lfw.zip to /content/
#
# •	Unzipped lfw.zip to /content/sample_data using below command
#
# !unzip /content/lfw.zip -d /content/sample_data

# %%
# !unzip /content/lfw.zip -d /content/sample_data
# Out:
# Archive:  /content/lfw.zip
#    creating: /content/sample_data/lfw/Aaron_Eckhart/
#   inflating: /content/sample_data/lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg
#    creating: /content/sample_data/lfw/Aaron_Guiel/
#   inflating: /content/sample_data/lfw/Aaron_Guiel/Aaron_Guiel_0001.jpg
#    creating: /content/sample_data/lfw/Aaron_Patterson/
#   inflating: /content/sample_data/lfw/Aaron_Patterson/Aaron_Patterson_0001.jpg
#    creating: /content/sample_data/lfw/Aaron_Peirsol/
#   inflating: /content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0001.jpg
#   inflating: /content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0002.jpg
#   inflating: /content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0003.jpg
#   inflating: /content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0004.jpg
#    creating: /content/sample_data/lfw/Aaron_Pena/
#   inflating: /content/sample_data/lfw/Aaron_Pena/Aaron_Pena_0001.jpg
#    creating: /content/sample_data/lfw/Aaron_Sorkin/
#   inflating: /content/sample_data/lfw/Aaron_Sorkin/Aaron_Sorkin_0001.jpg
#   inflating: /content/sample_data/lfw/Aaron_Sorkin/Aaron_Sorkin_0002.jpg
#    creating: /content/sample_data/lfw/Aaron_Tippin/
#   inflating: /content/sample_data/lfw/Aaron_Tippin/Aaron_Tippin_0001.jpg
#    creating: /content/sample_data/lfw/Abba_Eban/
#   inflating: /content/sample_data/lfw/Abba_Eban/Abba_Eban_0001.jpg
#    creating: /content/sample_data/lfw/Abbas_Kiarostami/
#   inflating: /content/sample_data/lfw/Abbas_Kiarostami/Abbas_Kiarostami_0001.jpg
#    creating: /content/sample_data/lfw/Abdel_Aziz_Al-Hakim/
#   inflating: /content/sample_data/lfw/Abdel_Aziz_Al-Hakim/Abdel_Aziz_Al-Hakim_0001.jpg
#    creating: /content/sample_data/lfw/Abdel_Madi_Shabneh/
#   inflating: /content/sample_data/lfw/Abdel_Madi_Shabneh/Abdel_Madi_Shabneh_0001.jpg
#    creating: /content/sample_data/lfw/Abdel_Nasser_Assidi/
#   inflating: /content/sample_data/lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0001.jpg
#   inflating: /content/sample_data/lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0002.jpg
#    creating: /content/sample_data/lfw/Abdoulaye_Wade/
#   inflating: /content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0001.jpg
#   inflating: /content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0002.jpg
#   inflating: /content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0003.jpg
#   inflating: /content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0004.jpg
#    creating: /content/sample_data/lfw/Abdul_Majeed_Shobokshi/
#   inflating: /content/sample_data/lfw/Abdul_Majeed_Shobokshi/Abdul_Majeed_Shobokshi_0001.jpg
#    creating: /content/sample_data/lfw/Abdul_Rahman/
#   inflating: /content/sample_data/lfw/Abdul_Rahman/Abdul_Rahman_0001.jpg
#    creating: /content/sample_data/lfw/Abdulaziz_Kamilov/
#   inflating: /content/sample_data/lfw/Abdulaziz_Kamilov/Abdulaziz_Kamilov_0001.jpg
#    creating: /content/sample_data/lfw/Abdullah/
#   inflating: /content/sample_data/lfw/Abdullah/Abdullah_0001.jpg
#   inflating: /content/sample_data/lfw/Abdullah/Abdullah_0002.jpg
#   inflating: /content/sample_data/lfw/Abdullah/Abdullah_0003.jpg
#   inflating: /content/sample_data/lfw/Abdullah/Abdullah_0004.jpg
#    creating: /content/sample_data/lfw/Abdullah_Ahmad_Badawi/
#   inflating: /content/sample_data/lfw/Abdullah_Ahmad_Badawi/Abdullah_Ahmad_Badawi_0001.jpg
#    creating: /content/sample_data/lfw/Abdullah_al-Attiyah/
#   inflating: /content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0001.jpg
#   inflating: /content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0002.jpg
#   inflating: /content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0003.jpg
#    creating: /content/sample_data/lfw/Abdullah_Gul/
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0001.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0002.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0003.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0004.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0005.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0006.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0007.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0008.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0009.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0010.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0011.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0012.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0013.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0014.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0015.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0016.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0017.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0018.jpg
#   inflating: /content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0019.jpg
#    creating: /content/sample_data/lfw/Abdullah_Nasseef/
#   inflating: /content/sample_data/lfw/Abdullah_Nasseef/Abdullah_Nasseef_0001.jpg
#    creating: /content/sample_data/lfw/Abdullatif_Sener/
#   inflating: /content/sample_data/lfw/Abdullatif_Sener/Abdullatif_Sener_0001.jpg
#   inflating: /content/sample_data/lfw/Abdullatif_Sener/Abdullatif_Sener_0002.jpg
#    creating: /content/sample_data/lfw/Abel_Aguilar/
#   inflating: /content/sample_data/lfw/Abel_Aguilar/Abel_Aguilar_0001.jpg
#    creating: /content/sample_data/lfw/Abel_Pacheco/
#   inflating: /content/sample_data/lfw/Abel_Pacheco/Abel_Pacheco_0001.jpg
#   inflating: /content/sample_data/lfw/Abel_Pacheco/Abel_Pacheco_0002.jpg
#   inflating: /content/sample_data/lfw/Abel_Pacheco/Abel_Pacheco_0003.jpg
#   inflating: /content/sample_data/lfw/Abel_Pacheco/Abel_Pacheco_0004.jpg
#    creating: /content/sample_data/lfw/Abid_Hamid_Mahmud_Al-Tikriti/
#   inflating: /content/sample_data/lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg
#   inflating: /content/sample_data/lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0002.jpg
#   inflating: /content/sample_data/lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0003.jpg
#    creating: /content/sample_data/lfw/Abner_Martinez/
#   inflating: /content/sample_data/lfw/Abner_Martinez/Abner_Martinez_0001.jpg
#    creating: /content/sample_data/lfw/Abraham_Foxman/
#   inflating: /content/sample_data/lfw/Abraham_Foxman/Abraham_Foxman_0001.jpg
#    creating: /content/sample_data/lfw/Aby_Har-Even/
#   inflating: /content/sample_data/lfw/Aby_Har-Even/Aby_Har-Even_0001.jpg
#    creating: /content/sample_data/lfw/Adam_Ant/
#   inflating: /content/sample_data/lfw/Adam_Ant/Adam_Ant_0001.jpg
#    creating: /content/sample_data/lfw/Adam_Freier/
#   inflating: /content/sample_data/lfw/Adam_Freier/Adam_Freier_0001.jpg
#    creating: /content/sample_data/lfw/Adam_Herbert/
#   inflating: /content/sample_data/lfw/Adam_Herbert/Adam_Herbert_0001.jpg
#    creating: /content/sample_data/lfw/Adam_Kennedy/
#   inflating: /content/sample_data/lfw/Adam_Kennedy/Adam_Kennedy_0001.jpg
#    creating: /content/sample_data/lfw/Adam_Mair/
#   inflating: /content/sample_data/lfw/Adam_Mair/Adam_Mair_0001.jpg
#    creating: /content/sample_data/lfw/Adam_Rich/
#   inflating: /content/sample_data/lfw/Adam_Rich/Adam_Rich_0001.jpg
#    creating: /content/sample_data/lfw/Adam_Sandler/
#   inflating: /content/sample_data/lfw/Adam_Sandler/Adam_Sandler_0001.jpg
#   inflating: /content/sample_data/lfw/Adam_Sandler/Adam_Sandler_0002.jpg
#   inflating: /content/sample_data/lfw/Adam_Sandler/Adam_Sandler_0003.jpg
#   inflating: /content/sample_data/lfw/Adam_Sandler/Adam_Sandler_0004.jpg
#    creating: /content/sample_data/lfw/Adam_Scott/
#   inflating: /content/sample_data/lfw/Adam_Scott/Adam_Scott_0001.jpg
#   inflating: /content/sample_data/lfw/Adam_Scott/Adam_Scott_0002.jpg
#    creating: /content/sample_data/lfw/Adel_Al-Jubeir/
#   inflating: /content/sample_data/lfw/Adel_Al-Jubeir/Adel_Al-Jubeir_0001.jpg
#   inflating: /content/sample_data/lfw/Adel_Al-Jubeir/Adel_Al-Jubeir_0002.jpg
#   inflating: /content/sample_data/lfw/Adel_Al-Jubeir/Adel_Al-Jubeir_0003.jpg
#    creating: /content/sample_data/lfw/Adelina_Avila/
#   inflating: /content/sample_data/lfw/Adelina_Avila/Adelina_Avila_0001.jpg
#    creating: /content/sample_data/lfw/Adisai_Bodharamik/
#   inflating: /content/sample_data/lfw/Adisai_Bodharamik/Adisai_Bodharamik_0001.jpg
#    creating: /content/sample_data/lfw/Adolfo_Aguilar_Zinser/
#   inflating: /content/sample_data/lfw/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0001.jpg
#   inflating: /content/sample_data/lfw/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0002.jpg
#   inflating: /content/sample_data/lfw/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0003.jpg
#    creating: /content/sample_data/lfw/Adolfo_Rodriguez_Saa/
#   inflating: /content/sample_data/lfw/Adolfo_Rodriguez_Saa/Adolfo_Rodriguez_Saa_0001.jpg
#   inflating: /content/sample_data/lfw/Adolfo_Rodriguez_Saa/Adolfo_Rodriguez_Saa_0002.jpg
#    creating: /content/sample_data/lfw/Adoor_Gopalakarishnan/
#   inflating: /content/sample_data/lfw/Adoor_Gopalakarishnan/Adoor_Gopalakarishnan_0001.jpg
#    creating: /content/sample_data/lfw/Adrian_Annus/
#   inflating: /content/sample_data/lfw/Adrian_Annus/Adrian_Annus_0001.jpg
#    creating: /content/sample_data/lfw/Adrian_Fernandez/
#   inflating: /content/sample_data/lfw/Adrian_Fernandez/Adrian_Fernandez_0001.jpg
#    creating: /content/sample_data/lfw/Adrian_McPherson/
#   inflating: /content/sample_data/lfw/Adrian_McPherson/Adrian_McPherson_0001.jpg
#   inflating: /content/sample_data/lfw/Adrian_McPherson/Adrian_McPherson_0002.jpg
#    creating: /content/sample_data/lfw/Adrian_Murrell/
#   inflating: /content/sample_data/lfw/Adrian_Murrell/Adrian_Murrell_0001.jpg
#    creating: /content/sample_data/lfw/Adrian_Nastase/
#   inflating: /content/sample_data/lfw/Adrian_Nastase/Adrian_Nastase_0001.jpg
#   inflating: /content/sample_data/lfw/Adrian_Nastase/Adrian_Nastase_0002.jpg
#    creating: /content/sample_data/lfw/Adriana_Lima/
#   inflating: /content/sample_data/lfw/Adriana_Lima/Adriana_Lima_0001.jpg
#    creating: /content/sample_data/lfw/Adriana_Perez_Navarro/
#   inflating: /content/sample_data/lfw/Adriana_Perez_Navarro/Adriana_Perez_Navarro_0001.jpg
#    creating: /content/sample_data/lfw/Adrianna_Zuzic/
#   inflating: /content/sample_data/lfw/Adrianna_Zuzic/Adrianna_Zuzic_0001.jpg
#    creating: /content/sample_data/lfw/Adrien_Brody/
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0001.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0002.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0003.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0004.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0005.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0006.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0007.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0008.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0009.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0010.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0011.jpg
#   inflating: /content/sample_data/lfw/Adrien_Brody/Adrien_Brody_0012.jpg
#    creating: /content/sample_data/lfw/Afton_Smith/
#   inflating: /content/sample_data/lfw/Afton_Smith/Afton_Smith_0001.jpg
#    creating: /content/sample_data/lfw/Agbani_Darego/
#   inflating: /content/sample_data/lfw/Agbani_Darego/Agbani_Darego_0001.jpg
#    creating: /content/sample_data/lfw/Agnelo_Queiroz/
#   inflating: /content/sample_data/lfw/Agnelo_Queiroz/Agnelo_Queiroz_0001.jpg
#    creating: /content/sample_data/lfw/Agnes_Bruckner/
#   inflating: /content/sample_data/lfw/Agnes_Bruckner/Agnes_Bruckner_0001.jpg
#    creating: /content/sample_data/lfw/Ahmad_Jbarah/
#   inflating: /content/sample_data/lfw/Ahmad_Jbarah/Ahmad_Jbarah_0001.jpg
#    creating: /content/sample_data/lfw/Ahmad_Masood/
#   inflating: /content/sample_data/lfw/Ahmad_Masood/Ahmad_Masood_0001.jpg
#   inflating: /content/sample_data/lfw/Ahmad_Masood/Ahmad_Masood_0002.jpg
#    creating: /content/sample_data/lfw/Ahmed_Ahmed/
#   inflating: /content/sample_data/lfw/Ahmed_Ahmed/Ahmed_Ahmed_0001.jpg
#    creating: /content/sample_data/lfw/Ahmed_Chalabi/
#   inflating: /content/sample_data/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0001.jpg
#   inflating: /content/sample_data/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0002.jpg
#   inflating: /content/sample_data/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0003.jpg
#   inflating: /content/sample_data/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0004.jpg
#   inflating: /content/sample_data/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0005.jpg
#    creating: /content/sample_data/lfw/Ahmed_Ghazi/
#   inflating: /content/sample_data/lfw/Ahmed_Ghazi/Ahmed_Ghazi_0001.jpg
#    creating: /content/sample_data/lfw/Ahmed_Ibrahim_Bilal/
#   inflating: /content/sample_data/lfw/Ahmed_Ibrahim_Bilal/Ahmed_Ibrahim_Bilal_0001.jpg
#    creating: /content/sample_data/lfw/Ahmed_Lopez/
#   inflating: /content/sample_data/lfw/Ahmed_Lopez/Ahmed_Lopez_0001.jpg
#    creating: /content/sample_data/lfw/Ahmed_Qureia/
#   inflating: /content/sample_data/lfw/Ahmed_Qureia/Ahmed_Qureia_0001.jpg
#    creating: /content/sample_data/lfw/Ahmet_Demir/
#   inflating: /content/sample_data/lfw/Ahmet_Demir/Ahmet_Demir_0001.jpg
#    creating: /content/sample_data/lfw/Ahmet_Necdet_Sezer/
#   inflating: /content/sample_data/lfw/Ahmet_Necdet_Sezer/Ahmet_Necdet_Sezer_0001.jpg
#   inflating: /content/sample_data/lfw/Ahmet_Necdet_Sezer/Ahmet_Necdet_Sezer_0002.jpg
#    creating: /content/sample_data/lfw/Ai_Sugiyama/
#   inflating: /content/sample_data/lfw/Ai_Sugiyama/Ai_Sugiyama_0001.jpg
#   inflating: /content/sample_data/lfw/Ai_Sugiyama/Ai_Sugiyama_0002.jpg
#   inflating: /content/sample_data/lfw/Ai_Sugiyama/Ai_Sugiyama_0003.jpg
#   inflating: /content/sample_data/lfw/Ai_Sugiyama/Ai_Sugiyama_0004.jpg
#   inflating: /content/sample_data/lfw/Ai_Sugiyama/Ai_Sugiyama_0005.jpg
#    creating: /content/sample_data/lfw/Aicha_El_Ouafi/
#   inflating: /content/sample_data/lfw/Aicha_El_Ouafi/Aicha_El_Ouafi_0001.jpg
#   inflating: /content/sample_data/lfw/Aicha_El_Ouafi/Aicha_El_Ouafi_0002.jpg
#   inflating: /content/sample_data/lfw/Aicha_El_Ouafi/Aicha_El_Ouafi_0003.jpg
#    creating: /content/sample_data/lfw/Aidan_Quinn/
#   inflating: /content/sample_data/lfw/Aidan_Quinn/Aidan_Quinn_0001.jpg
#    creating: /content/sample_data/lfw/Aileen_Riggin_Soule/
#   inflating: /content/sample_data/lfw/Aileen_Riggin_Soule/Aileen_Riggin_Soule_0001.jpg
#    creating: /content/sample_data/lfw/Ain_Seppik/
#   inflating: /content/sample_data/lfw/Ain_Seppik/Ain_Seppik_0001.jpg
#    creating: /content/sample_data/lfw/Ainsworth_Dyer/
#   inflating: /content/sample_data/lfw/Ainsworth_Dyer/Ainsworth_Dyer_0001.jpg
#    creating: /content/sample_data/lfw/Aishwarya_Rai/
#   inflating: /content/sample_data/lfw/Aishwarya_Rai/Aishwarya_Rai_0001.jpg
#    creating: /content/sample_data/lfw/Aitor_Gonzalez/
#   inflating: /content/sample_data/lfw/Aitor_Gonzalez/Aitor_Gonzalez_0001.jpg
#   inflating: /content/sample_data/lfw/Aitor_Gonzalez/Aitor_Gonzalez_0002.jpg
#    creating: /content/sample_data/lfw/Aiysha_Smith/
#   inflating: /content/sample_data/lfw/Aiysha_Smith/Aiysha_Smith_0001.jpg
#    creating: /content/sample_data/lfw/AJ_Cook/
#   inflating: /content/sample_data/lfw/AJ_Cook/AJ_Cook_0001.jpg
#    creating: /content/sample_data/lfw/AJ_Lamas/
#   inflating: /content/sample_data/lfw/AJ_Lamas/AJ_Lamas_0001.jpg
#    creating: /content/sample_data/lfw/Ajit_Agarkar/
#   inflating: /content/sample_data/lfw/Ajit_Agarkar/Ajit_Agarkar_0001.jpg
#    creating: /content/sample_data/lfw/Akbar_Al_Baker/
#   inflating: /content/sample_data/lfw/Akbar_Al_Baker/Akbar_Al_Baker_0001.jpg
#    creating: /content/sample_data/lfw/Akbar_Hashemi_Rafsanjani/
#   inflating: /content/sample_data/lfw/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0001.jpg
#   inflating: /content/sample_data/lfw/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0002.jpg
#   inflating: /content/sample_data/lfw/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0003.jpg
#    creating: /content/sample_data/lfw/Akhmed_Zakayev/
#   inflating: /content/sample_data/lfw/Akhmed_Zakayev/Akhmed_Zakayev_0001.jpg
#   inflating: /content/sample_data/lfw/Akhmed_Zakayev/Akhmed_Zakayev_0002.jpg
#   inflating: /content/sample_data/lfw/Akhmed_Zakayev/Akhmed_Zakayev_0003.jpg
#    creating: /content/sample_data/lfw/Akiko_Morigami/
#   inflating: /content/sample_data/lfw/Akiko_Morigami/Akiko_Morigami_0001.jpg
#    creating: /content/sample_data/lfw/Akmal_Taher/
#   inflating: /content/sample_data/lfw/Akmal_Taher/Akmal_Taher_0001.jpg
#    creating: /content/sample_data/lfw/Al_Cardenas/
#   inflating: /content/sample_data/lfw/Al_Cardenas/Al_Cardenas_0001.jpg
#    creating: /content/sample_data/lfw/Al_Davis/
#   inflating: /content/sample_data/lfw/Al_Davis/Al_Davis_0001.jpg
#   inflating: /content/sample_data/lfw/Al_Davis/Al_Davis_0002.jpg
#    creating: /content/sample_data/lfw/Al_Gore/
#   inflating: /content/sample_data/lfw/Al_Gore/Al_Gore_0001.jpg
#   inflating: /content/sample_data/lfw/Al_Gore/Al_Gore_0002.jpg
#   inflating: /content/sample_data/lfw/Al_Gore/Al_Gore_0003.jpg
#   inflating: /content/sample_data/lfw/Al_Gore/Al_Gore_0004.jpg
#   inflating: /content/sample_data/lfw/Al_Gore/Al_Gore_0005.jpg
#   inflating: /content/sample_data/lfw/Al_Gore/Al_Gore_0006.jpg
#   inflating: /content/sample_data/lfw/Al_Gore/Al_Gore_0007.jpg
#   inflating: /content/sample_data/lfw/Al_Gore/Al_Gore_0008.jpg
#    creating: /content/sample_data/lfw/Al_Leiter/
#   inflating: /content/sample_data/lfw/Al_Leiter/Al_Leiter_0001.jpg
#    creating: /content/sample_data/lfw/Al_Pacino/
#   inflating: /content/sample_data/lfw/Al_Pacino/Al_Pacino_0001.jpg
#   inflating: /content/sample_data/lfw/Al_Pacino/Al_Pacino_0002.jpg
#   inflating: /content/sample_data/lfw/Al_Pacino/Al_Pacino_0003.jpg
#    creating: /content/sample_data/lfw/Al_Sharpton/
#   inflating: /content/sample_data/lfw/Al_Sharpton/Al_Sharpton_0001.jpg
#   inflating: /content/sample_data/lfw/Al_Sharpton/Al_Sharpton_0002.jpg
#   inflating: /content/sample_data/lfw/Al_Sharpton/Al_Sharpton_0003.jpg
#   inflating: /content/sample_data/lfw/Al_Sharpton/Al_Sharpton_0004.jpg
#   inflating: /content/sample_data/lfw/Al_Sharpton/Al_Sharpton_0005.jpg
#   inflating: /content/sample_data/lfw/Al_Sharpton/Al_Sharpton_0006.jpg
#   inflating: /content/sample_data/lfw/Al_Sharpton/Al_Sharpton_0007.jpg
#    creating: /content/sample_data/lfw/Alain_Cervantes/
#   inflating: /content/sample_data/lfw/Alain_Cervantes/Alain_Cervantes_0001.jpg
#    creating: /content/sample_data/lfw/Alain_Ducasse/
#   inflating: /content/sample_data/lfw/Alain_Ducasse/Alain_Ducasse_0001.jpg
#    creating: /content/sample_data/lfw/Alan_Ball/
#   inflating: /content/sample_data/lfw/Alan_Ball/Alan_Ball_0001.jpg
#   inflating: /content/sample_data/lfw/Alan_Ball/Alan_Ball_0002.jpg
#    creating: /content/sample_data/lfw/Alan_Dershowitz/
#   inflating: /content/sample_data/lfw/Alan_Dershowitz/Alan_Dershowitz_0001.jpg
#    creating: /content/sample_data/lfw/Alan_Dreher/
#   inflating: /content/sample_data/lfw/Alan_Dreher/Alan_Dreher_0001.jpg
#    creating: /content/sample_data/lfw/Alan_Greenspan/
#   inflating: /content/sample_data/lfw/Alan_Greenspan/Alan_Greenspan_0001.jpg
#   inflating: /content/sample_data/lfw/Alan_Greenspan/Alan_Greenspan_0002.jpg
#   inflating: /content/sample_data/lfw/Alan_Greenspan/Alan_Greenspan_0003.jpg
#   inflating: /content/sample_data/lfw/Alan_Greenspan/Alan_Greenspan_0004.jpg
#   inflating: /content/sample_data/lfw/Alan_Greenspan/Alan_Greenspan_0005.jpg
#    creating: /content/sample_data/lfw/Alan_Greer/
#   inflating: /content/sample_data/lfw/Alan_Greer/Alan_Greer_0001.jpg
#    creating: /content/sample_data/lfw/Alan_
#   inflating: /content/sample_data/lfw/Alberto_Acosta/Alberto_Acosta_0001.jpg
#    creating: /content/sample_data/lfw/Alberto_Fujimori/
#   inflating: /content/sample_data/lfw/Alberto_Fujimori/Alberto_Fujimori_0001.jpg
#   inflating: /content/sample_data/lfw/Alberto_Fujimori/Alberto_Fujimori_0002.jpg
#    creating: /content/sample_data/lfw/Alberto_Gonzales/
#   inflating: /content/sample_data/lfw/Alberto_Gonzales/Alberto_Gonzales_0001.jpg
#    creating: /content/sample_data/lfw/Alberto_Ruiz_Gallardon/
#   inflating: /content/sample_data/lfw/Alberto_Ruiz_Gallardon/Alberto_Ruiz_Gallardon_0001.jpg
#   inflating: /content/sample_data/lfw/Alberto_Ruiz_Gallardon/Alberto_Ruiz_Gallardon_0002.jpg
#    creating: /content/sample_data/lfw/Alberto_Sordi/
#   inflating: /content/sample_data/lfw/Alberto_Sordi/Alberto_Sordi_0001.jpg
#    creating: /content/sample_data/lfw/Albrecht_Mentz/
#   inflating: /content/sample_data/lfw/Albrecht_Mentz/Albrecht_Mentz_0001.jpg
#   inflating: /content/sample_data/lfw/Albrecht_Mentz/Albrecht_Mentz_0002.jpg
#    creating: /content/sample_data/lfw/Aldo_Paredes/
#   inflating: /content/sample_data/lfw/Aldo_Paredes/Aldo_Paredes_0001.jpg
#   inflating: /content/sample_data/lfw/Aldo_Paredes/Aldo_Paredes_0002.jpg
#    creating: /content/sample_data/lfw/Alec_Baldwin/
#   inflating: /content/sample_data/lfw/Alec_Baldwin/Alec_Baldwin_0001.jpg
#   inflating: /content/sample_data/lfw/Alec_Baldwin/Alec_Baldwin_0002.jpg
#   inflating: /content/sample_data/lfw/Alec_Baldwin/Alec_Baldwin_0003.jpg
#   inflating: /content/sample_data/lfw/Alec_Baldwin/Alec_Baldwin_0004.jpg
#    creating: /content/sample_data/lfw/Alecos_Markides/
#   inflating: /content/sample_data/lfw/Alecos_Markides/Alecos_Markides_0001.jpg
#    creating: /content/sample_data/lfw/Alejandro_Atchugarry/
#   inflating: /content/sample_data/lfw/Alejandro_Atchugarry/Alejandro_Atchugarry_0001.jpg
#   inflating: /content/sample_data/lfw/Alejandro_Atchugarry/Alejandro_Atchugarry_0002.jpg
#    creating: /content/sample_data/lfw/Alejandro_Avila/
#   inflating: /content/sample_data/lfw/Alejandro_Avila/Alejandro_Avila_0001.jpg
#   inflating: /content/sample_data/lfw/Alejandro_Avila/Alejandro_Avila_0002.jpg
#   inflating: /content/sample_data/lfw/Alejandro_Avila/Alejandro_Avila_0003.jpg
#    creating: /content/sample_data/lfw/Alejandro_Fernandez/
#   inflating: /content/sample_data/lfw/Alejandro_Fernandez/Alejandro_Fernandez_0001.jpg
#    creating: /content/sample_data/lfw/Alejandro_Gonzalez_Inarritu/
#   inflating: /content/sample_data/lfw/Alejandro_Gonzalez_Inarritu/Alejandro_Gonzalez_Inarritu_0001.jpg
#    creating: /content/sample_data/lfw/Alejandro_Lembo/
#   inflating: /content/sample_data/lfw/Alejandro_Lembo/Alejandro_Lembo_0001.jpg
#    creating: /content/sample_data/lfw/Alejandro_Lerner/
#   inflating: /content/sample_data/lfw/Alejandro_Lerner/Alejandro_Lerner_0001.jpg
#    creating: /content/sample_data/lfw/Alejandro_Lopez/
#   inflating: /content/sample_data/lfw/Alejandro_Lopez/Alejandro_Lopez_0001.jpg
#    creating: /content/sample_data/lfw/Alejandro_Toledo/
#   inflating: /content/sample_data/lfw/Alejandro_Toledo/Alejandro_Toledo_
#   inflating: /content/sample_data/lfw/Ali_Naimi/Ali_Naimi_0001.jpg
#   inflating: /content/sample_data/lfw/Ali_Naimi/Ali_Naimi_0002.jpg
#   inflating: /content/sample_data/lfw/Ali_Naimi/Ali_Naimi_0003.jpg
#   inflating: /content/sample_data/lfw/Ali_Naimi/Ali_Naimi_0004.jpg
#   inflating: /content/sample_data/lfw/Ali_Naimi/Ali_Naimi_0005.jpg
#   inflating: /content/sample_data/lfw/Ali_Naimi/Ali_Naimi_0006.jpg
#   inflating: /content/sample_data/lfw/Ali_Naimi/Ali_Naimi_0007.jpg
#   inflating: /content/sample_data/lfw/Ali_Naimi/Ali_Naimi_0008.jpg
#    creating: /content/sample_data/lfw/Alice_Fisher/
#   inflating: /content/sample_data/lfw/Alice_Fisher/Alice_Fisher_0001.jpg
#   inflating: /content/sample_data/lfw/Alice_Fisher/Alice_Fisher_0002.jpg
#    creating: /content/sample_data/lfw/Alicia_Hollowell/
#   inflating: /content/sample_data/lfw/Alicia_Hollowell/Alicia_Hollowell_0001.jpg
#    creating: /content/sample_data/lfw/Alicia_Keys/
#   inflating: /content/sample_data/lfw/Alicia_Keys/Alicia_Keys_0001.jpg
#    creating: /content/sample_data/lfw/Alicia_Molik/
#   inflating: /content/sample_data/lfw/Alicia_Molik/Alicia_Molik_0001.jpg
#    creating: /content/sample_data/lfw/Alicia_Silverstone/
#   inflating: /content/sample_data/lfw/Alicia_Silverstone/Alicia_Silverstone_0001.jpg
#   inflating: /content/sample_data/lfw/Alicia_Silverstone/Alicia_Silverstone_0002.jpg
#    creating: /content/sample_data/lfw/Alicia_Witt/
#   inflating: /content/sample_data/lfw/Alicia_Witt/Alicia_Witt_0001.jpg
#    creating: /content/sample_data/lfw/Alimzhan_Tokhtakhounov/
#   inflating: /content/sample_data/lfw/Alimzhan_Tokhtakhounov/Alimzhan_Tokhtakhounov_0001.jpg
#   inflating: /content/sample_data/lfw/Alimzhan_Tokhtakhounov/Alimzhan_Tokhtakhounov_0002.jpg
#    creating: /content/sample_data/lfw/Alina_Kabaeva/
#   inflating: /content/sample_data/lfw/Alina_Kabaeva/Alina_Kabaeva_0001.jpg
#    creating: /content/sample_data/lfw/Aline_Chretien/
#   inflating: /content/sample_data/lfw/Aline_Chretien/Aline_Chretien_0001.jpg
#    creating: /content/sample_data/lfw/Alisha_Richman/
#   inflating: /content/sample_data/lfw/Alisha_Richman/Alisha_Richman_0001.jpg
#    creating: /content/sample_data/lfw/Alison_Krauss/
#   inflating: /content/sample_data/lfw/Alison_Krauss/Alison_Krauss_0001.jpg
#    creating: /content/sample_data/lfw/Alison_Lohman/
#   inflating: /content/sample_data/lfw/Alison_Lohman/Alison_Lohman_0001.jpg
#   inflating: /content/sample_data/lfw/Alison_Lohman/Alison_Lohman_0002.jpg
#    creating: /content/sample_data/lfw/Alistair_MacDonald/
#   inflating: /content/sample_data/lfw/Alistair_MacDonald/Alistair_MacDonald_0001.jpg
#    creating: /content/sample_data/lfw/Allan_Houston/
#   inflating: /content/sample_data/lfw/Allan_Houston/Allan_Houston_0001.jpg
#    creating: /content/sample_data/lfw/Allan_Kemakeza/
#   inflating: /content/sample_data/lfw/Allan_Kemakeza/Allan_Kemakeza_0001.jpg
#    creating: /content/sample_data/lfw/Allan_Wagner/
#   inflating: /content/sample_data/lfw/Allan_Wagner/Allan_Wagner_0001.jpg
#    creating: /content/sample_data/lfw/Allen_Iverson/
#   inflating: /content/sample_data/lfw/Allen_Iverson/Allen_Iverson_0001.jpg
#   inflating: /content/sample_data/lfw/Allen_Iverson/Allen_Iverson_0002.jpg
0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Glassroth/
#   inflating: /content/sample_data/lfw/Stephen_Glassroth/Stephen_Glassroth_0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Joseph/
#   inflating: /content/sample_data/lfw/Stephen_Joseph/Stephen_Joseph_0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Keener/
#   inflating: /content/sample_data/lfw/Stephen_Keener/Stephen_Keener_0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Oake/
#   inflating: /content/sample_data/lfw/Stephen_Oake/Stephen_Oake_0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Push/
#   inflating: /content/sample_data/lfw/Stephen_Push/Stephen_Push_0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Silas/
#   inflating: /content/sample_data/lfw/Stephen_Silas/Stephen_Silas_0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Swindal/
#   inflating: /content/sample_data/lfw/Stephen_Swindal/Stephen_Swindal_0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Thompson/
#   inflating: /content/sample_data/lfw/Stephen_Thompson/Stephen_Thompson_0001.jpg
#    creating: /content/sample_data/lfw/Stephen_Webster/
#   inflating: /content/sample_data/lfw/Stephen_Webster/Stephen_Webster_0001.jpg
#    creating: /content/sample_data/lfw/Sterling_Hitchcock/
#   inflating: /content/sample_data/lfw/Sterling_Hitchcock/Sterling_Hitchcock_0001.jpg
#    creating: /content/sample_data/lfw/Steve_Alford/
#   inflating: /content/sample_data/lfw/Steve_Alford/Steve_Alford_0001.jpg
#    creating: /content/sample_data/lfw/Steve_Allan/
#   inflating: /content/sample_data/lfw/Steve_Allan/Steve_Allan_0001.jpg
#    creating: /content/sample_data/lfw/Steve_Allee/
#   inflating: /content/sample_data/lfw/Steve_Allee/Steve_Allee_0001.jpg
#    creating: /content/sample_data/lfw/Tara_Dawn_Christensen/
#   inflating: /content/sample_data/lfw/Tara_Dawn_Christensen/Tara_Dawn_Christensen_0001.jpg
#    creating: /content/sample_data/lfw/Ted_Costa/
#   inflating: /content/sample_data/lfw/Ted_Costa/Ted_Costa_0001.jpg
#    creating: /content/sample_data/lfw/Ted_Maher/
#   inflating: /content/sample_data/lfw/Ted_Maher/Ted_Maher_0001.jpg
#   inflating: /content/sample_data/lfw/Ted_Maher/Ted_Maher_0002.jpg
#    creating: /content/sample_data/lfw/Ted_Nolan/
#   inflating: /content/sample_data/lfw/Ted_Nolan/Ted_Nolan_0001.jpg
#    creating: /content/sample_data/lfw/Ted_Turner/
#   inflating: /content/sample_data/lfw/Ted_Turner/Ted_Turner_0001.jpg
#    creating: /content/sample_data/lfw/Ted_Washington/
#   inflating: /content/sample_data/lfw/Ted_Washington/Ted_Washington_0001.jpg
#    creating: /content/sample_data/lfw/Ted_Williams/
#   inflating: /content/sample_data/lfw/Ted_Williams/Ted_Williams_0001.jpg
#    creating: /content/sample_data/lfw/Teddy_Kollek/
#   inflating: /content/sample_data/lfw/Teddy_Kollek/Teddy_Kollek_0001.jpg
#    creating: /content/sample_data/lfw/Terence_Newman/
#   inflating: /content/sample_data/lfw/Terence_Newman/Terence_Newman_0001.jpg
#    creating: /content/sample_data/lfw/Teresa_Graves/
#   inflating: /content/sample_data/lfw/Teresa_Graves/Teresa_Graves_0001.jpg
#    creating: /content/sample_data/lfw/Teresa_Heinz_Kerry/
#   inflating: /content/sample_data/lfw/Teresa_Heinz_Kerry/Teresa_Heinz_Kerry_0001.jpg
#    creating: /content/sample_data/lfw/Teresa_Williams/
#   inflating: /content/sample_data/lfw/Teresa_Williams/Teresa_Williams_0001.jpg
#    creating: /content/sample_data/lfw/Teresa_Worbis/
#   inflating: /content/sample_data/lfw/Teresa_Worbis/Teresa_Worbis_0001.jpg
#    creating: /content/sample_data/lfw/Teri_Files/
#   inflating: /content/sample_data/lfw/Teri_Files/Teri_Files_0001.jpg
#    creating: /content/sample_data/lfw/Zach_Safrin/
#   inflating: /content/sample_data/lfw/Zach_Safrin/Zach_Safrin_0001.jpg

# %% [markdown]
# •	**Create files path list**

# %%
import os
path =r'/content/sample_data/lfw'
list_of_files = []
for root, dirs, files in os.walk(path):
	for file in files:
		list_of_files.append(os.path.join(root,file))

len(list_of_files)
# Out:
# 1508

# %% [markdown]
# **•	Created files path list and respective labels in sorted order**

# %%
imgspaths= []
imglabels=[]
for imgpath in sorted(list_of_files):
   imgspaths.append(imgpath)
   temp=imgpath.split("/")
   imglabels.append(temp[len(temp)-2])

print(imgspaths)
print(imglabels)
# Out:
# ['/content/sample_data/lfw/AJ_Cook/AJ_Cook_0001.jpg', '/content/sample_data/lfw/AJ_Lamas/AJ_Lamas_0001.jpg', '/content/sample_data/lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg', '/content/sample_data/lfw/Aaron_Guiel/Aaron_Guiel_0001.jpg', '/content/sample_data/lfw/Aaron_Patterson/Aaron_Patterson_0001.jpg', '/content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0001.jpg', '/content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0002.jpg', '/content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0003.jpg', '/content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0004.jpg', '/content/sample_data/lfw/Aaron_Pena/Aaron_Pena_0001.jpg', '/content/sample_data/lfw/Aaron_Sorkin/Aaron_Sorkin_0001.jpg', '/content/sample_data/lfw/Aaron_Sorkin/Aaron_Sorkin_0002.jpg', '/content/sample_data/lfw/Aaron_Tippin/Aaron_Tippin_0001.jpg', '/content/sample_data/lfw/Abba_Eban/Abba_Eban_0001.jpg', '/content/sample_data/lfw/Abbas_Kiarostami/Abbas_Kiarostami_0001.jpg', '/content/sample_data/lfw/Abdel_Aziz_Al-Hakim/Abdel_Aziz_Al-Hakim_0001.jpg', '/content/sample_data/lfw/Abdel_Madi_Shabneh/Abdel_Madi_Shabneh_0001.jpg', '/content/sample_data/lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0001.jpg', '/content/sample_data/lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0002.jpg', '/content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0001.jpg', '/content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0002.jpg', '/content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0003.jpg', '/content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0004.jpg', '/content/sample_data/lfw/Abdul_Majeed_Shobokshi/Abdul_Majeed_Shobokshi_0001.jpg', '/content/sample_data/lfw/Abdul_Rahman/Abdul_Rahman_0001.jpg', '/content/sample_data/lfw/Abdulaziz_Kamilov/Abdulaziz_Kamilov_0001.jpg', '/content/sample_data/lfw/Abdullah/Abdullah_0001.jpg', '/content/sample_data/lfw/Abdullah/Abdullah_0002.jpg', '/content/sample_data/lfw/Abdullah/Abdullah_0003.jpg', '/content/sample_data/lfw/Abdullah/Abdullah_0004.jpg', '/content/sample_data/lfw/Abdullah_Ahmad_Badawi/Abdullah_Ahmad_Badawi_0001.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0001.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0002.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0003.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0004.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0005.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0006.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0007.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0008.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0009.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0010.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0011.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0012.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0013.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0014.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0015.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0016.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0017.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0018.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0019.jpg', '/content/sample_data/lfw/Abdullah_Nasseef/Abdullah_Nasseef_0001.jpg', '/content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0001.jpg', '/content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0002.jpg', '/content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0003.jp
 'Al_Gore', 'Al_Gore', 'Al_Gore', 'Al_Gore', 'Al_Gore', 'Al_Gore', 'Al_Gore', 'Al_Gore', 'Al_Leiter', 'Al_Pacino', 'Al_Pacino', 'Al_Pacino', 'Al_Sharpton', 'Al_Sharpton', 'Al_Sharpton', 'Al_Sharpton', 'Al_Sharpton', 'Al_Sharpton', 'Al_Sharpton', 'Alain_Cervantes', 'Alain_Ducasse', 'Alan_Ball', 'Alan_Ball', 'Alan_Dershowitz', 'Alan_Dreher', 'Alan_Greenspan', 'Alan_Greenspan', 'Alan_Greenspan', 'Alan_Greenspan', 'Alan_Greenspan', 'Alan_Greer', 'Alan_Jackson', 'Alan_Mulally', 'Alan_Mulally', 'Alan_Stonecipher', 'Alan_Tang_Kwong-wing', 'Alan_Trammell', 'Alan_Zemaitis', 'Alanis_Morissette', 'Alanna_Ubach', 'Alastair_Campbell', 'Alastair_Campbell', 'Alastair_Campbell', 'Alastair_Campbell', 'Alastair_Campbell', 'Alastair_Johnston', 'Albaro_Recoba', 'Albert_Brooks', 'Albert_Costa', 'Albert_Costa', 'Albert_Costa', 'Albert_Costa', 'Albert_Costa', 'Albert_Costa', 'Albert_Montanes', 'Albert_Pujols', 'Alberta_Lee', 'Alberto_Acosta', 'Alberto_Fujimori', 'Alberto_Fujimori', 'Alberto_Gonzales', 'Alberto_Ruiz_Gallardon', 'Alberto_Ruiz_Gallardon', 'Alberto_Sordi', 'Albrecht_Mentz', 'Albrecht_Mentz', 'Aldo_Paredes', 'Aldo_Paredes', 'Alec_Baldwin', 'A ...

# %% [markdown]
# **•	Extract features of image: resized image with (224,224) pixels and converted image to color.  Used baseline model using VGG16. Extracted features array from fully connected layer.**

# %%
# Import the libraries
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model
from pathlib import Path
from PIL import Image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

class IMGFeatureExtractor:
    def __init__(self):
        # Use VGG-16 as the architecture and ImageNet for the weight
        base_model = VGG16(weights='imagenet')
        # Customize the model to return features from fully-connected layer
        self.model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)
    def extractfeatures(self, img):
        # Resize the image
        img = img.resize((224, 224))
        # Convert the image color space
        img = img.convert('RGB')
        # Reformat the image
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        # Extract Features
        feature = self.model.predict(x)[0]
        norm=np.linalg.norm(feature)
        return feature/norm,norm

# %% [markdown]
# **•	Below function is to plot similar images:**

# %%
import matplotlib.pyplot as plt
import numpy as np
def Showsimilarpictures(scores):
  axes=[]
  fig=plt.figure(figsize=(8,8))
  for a in range(len(scores)):
      score = scores[a]
      axes.append(fig.add_subplot(6, 6, a+1))
      subplot_title=str(score[0])
      axes[-1].set_title(subplot_title)  
      plt.axis('off')
      plt.imshow(Image.open(score[1]))
  fig.tight_layout()
  plt.show()

# %% [markdown]
# **•	Extract all images features and save in array. It took more than 30 min without GPU**

# %%
from PIL import Image
from pathlib import Path
import numpy as np
# Iterate through images 
features =[]
featuresnorms= []
imagepaths= []
fe = IMGFeatureExtractor()
def ExtractAllImagesFeatures(fe):
    for img_path in sorted(list_of_files):
        #print(img_path) 
      feature,featurenorm = fe.extractfeatures(img=Image.open(img_path))
      features.append(feature)
      featuresnorms.append(featurenorm)
            #print(feature,"=============",featurenorm)
      imagepaths.append(img_path)
      #print(img_path)
      #np.save(feature_path, feature)
    feature_path = Path("/content/sample_data/Imagesfeatures.npy") 
    np.save(feature_path, features)
    print(imagepaths)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 3s 0us/step
# 553476096/553467096 [==============================] - 3s 0us/step

# %% [markdown]
# **•	Saved all images features numpy array in npy file for future use. The features file can be used for search, instead of extracting features again. All images features extraction (1508 images) took 806 seconds using without GPU.**

# %%
from PIL import ImageFile
import matplotlib.pyplot as plt
import numpy as np
import time
starttime=time.time()
ImageFile.LOAD_TRUNCATED_IMAGES = True
ExtractAllImagesFeatures(fe)
endtime=time.time()
print("All images features extraction time ",round(endtime-starttime)," seconds")
Allimagesfeatures = np.load('/content/sample_data/Imagesfeatures.npy')
#print(Allimagesfeatures)
#print(Allimagesfeatures.shape)
# Out:
# ['/content/sample_data/lfw/AJ_Cook/AJ_Cook_0001.jpg', '/content/sample_data/lfw/AJ_Lamas/AJ_Lamas_0001.jpg', '/content/sample_data/lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg', '/content/sample_data/lfw/Aaron_Guiel/Aaron_Guiel_0001.jpg', '/content/sample_data/lfw/Aaron_Patterson/Aaron_Patterson_0001.jpg', '/content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0001.jpg', '/content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0002.jpg', '/content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0003.jpg', '/content/sample_data/lfw/Aaron_Peirsol/Aaron_Peirsol_0004.jpg', '/content/sample_data/lfw/Aaron_Pena/Aaron_Pena_0001.jpg', '/content/sample_data/lfw/Aaron_Sorkin/Aaron_Sorkin_0001.jpg', '/content/sample_data/lfw/Aaron_Sorkin/Aaron_Sorkin_0002.jpg', '/content/sample_data/lfw/Aaron_Tippin/Aaron_Tippin_0001.jpg', '/content/sample_data/lfw/Abba_Eban/Abba_Eban_0001.jpg', '/content/sample_data/lfw/Abbas_Kiarostami/Abbas_Kiarostami_0001.jpg', '/content/sample_data/lfw/Abdel_Aziz_Al-Hakim/Abdel_Aziz_Al-Hakim_0001.jpg', '/content/sample_data/lfw/Abdel_Madi_Shabneh/Abdel_Madi_Shabneh_0001.jpg', '/content/sample_data/lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0001.jpg', '/content/sample_data/lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0002.jpg', '/content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0001.jpg', '/content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0002.jpg', '/content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0003.jpg', '/content/sample_data/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0004.jpg', '/content/sample_data/lfw/Abdul_Majeed_Shobokshi/Abdul_Majeed_Shobokshi_0001.jpg', '/content/sample_data/lfw/Abdul_Rahman/Abdul_Rahman_0001.jpg', '/content/sample_data/lfw/Abdulaziz_Kamilov/Abdulaziz_Kamilov_0001.jpg', '/content/sample_data/lfw/Abdullah/Abdullah_0001.jpg', '/content/sample_data/lfw/Abdullah/Abdullah_0002.jpg', '/content/sample_data/lfw/Abdullah/Abdullah_0003.jpg', '/content/sample_data/lfw/Abdullah/Abdullah_0004.jpg', '/content/sample_data/lfw/Abdullah_Ahmad_Badawi/Abdullah_Ahmad_Badawi_0001.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0001.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0002.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0003.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0004.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0005.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0006.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0007.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0008.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0009.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0010.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0011.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0012.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0013.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0014.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0015.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0016.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0017.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0018.jpg', '/content/sample_data/lfw/Abdullah_Gul/Abdullah_Gul_0019.jpg', '/content/sample_data/lfw/Abdullah_Nasseef/Abdullah_Nasseef_0001.jpg', '/content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0001.jpg', '/content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0002.jpg', '/content/sample_data/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0003.jpg', '/content/sample_data/lfw/Abdullatif_Sener/Abdullatif_Sener_0001.jpg', '/content/sample_data/lfw/Abdullatif_Sener/Abdullatif_Sener_0002.jpg', '/content/sample_data/lfw/Abel_Aguilar/Abel_Aguilar_0001.jpg', '/content/sample_data/lfw/Abel_Pacheco/Abel_Pacheco_0001.jpg', '/content/sample_data/lfw/Abel_Pacheco/Abel_Pacheco_0002.jpg', '/content/sample_data/lfw/Abel_Pacheco/Abel_Pacheco_0003.jpg', '/content/sample_data/lfw/Abel_Pacheco/Abel_Pacheco_0004.jpg', '/content/ ...
# All images features extraction time  888  seconds

# %% [markdown]
# •	**Loaded random image and extracted it’s features. It took 2 seconds. Found distance between query image features and all images features. Considered 25 images with shortest distance to query image as similar images( it is using KNN and L2 norm). Finding similar images took 1.57 seconds
# Below is code :**

# %%
# Import the libraries
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import random
import time
starttime=time.time()
queryImg = IMGFeatureExtractor()
# grab a random query image
query_image_idx = int(len(imgspaths) * random.random())
print(imglabels[query_image_idx])
# let's display the image
img1=Image.open(imgspaths[query_image_idx])
display(img1)
# Extract its features
queryImgFE,imgnorm = queryImg.extractfeatures(img1)
endtime=time.time()
print("Query Image features extraction time ",round(endtime-starttime)," seconds")
starttime=time.time()
# Calculate the similarity (distance) between images
dists = np.linalg.norm(features - queryImgFE, axis=1)
#print(len(dists)," ",len(imgspaths))
print(" Similar Images \n ==============================")
# Extract 36 images that have lowest distance
ids1 = np.argsort(dists)[:36]
#print(ids1)
scores = [(dists[id], imgspaths[id]) for id in ids1]
Showsimilarpictures(scores)
endtime=time.time()
print("similarity images search time :",(endtime-starttime)," seconds")
# Out:
# Ahmed_Ghazi
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F91F4C4FE10>
# Query Image features extraction time  4  seconds
#  Similar Images
#  ==============================
# similarity images search time : 1.7144105434417725  seconds

# %% [markdown]
# **	Image search Engine model implementation using Sklearn library NearestNeighbors:**

# %%
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import numpy as np
def  FindNearestNeighbors(k,Allimagesfeatures,queryImgFE,idx):
  starttime=time.time()
  # set desired number of neighbors
  neigh = NearestNeighbors(n_neighbors=k)
  neigh.fit(Allimagesfeatures)
  # select indices of k nearest neighbors of the vectors in the input list
  distances,neighbors = neigh.kneighbors([queryImgFE])
  #print(ids1)
  #scores = [(dists[id], imgspaths[id]) for id in ids1]
  if len(Allimagesfeatures)> len(imgspaths):
      scores = [(distances[0][i],imgspaths[idx[neighbors[0][i]]]) for i in range(neighbors.shape[1])]
  else:  
      scores = [(distances[0][i],imgspaths[neighbors[0][i]]) for i in range(neighbors.shape[1])]
  # Visualize the result
  #print(len(scores))
  print(imglabels[query_image_idx])
  display(img1)
  axes=[]
  fig=plt.figure(figsize=(8,8))
  print(" Similar Images as below \n ==============================")
  for j in range(len(scores)):
    score = scores[j]
    if k>5 :
      axes.append(fig.add_subplot(k/5, 5, j+1))
    else:
      axes.append(fig.add_subplot(1, 5, j+1))
    subplot_title=score[0]
    axes[-1].set_title(subplot_title)  
    plt.axis('off')
    plt.imshow(Image.open(score[1]))
  fig.tight_layout()
  plt.show()
  endtime=time.time()
  print("similarity images search done in ",(endtime-starttime)," seconds")

# %%
import numpy as np
idx1=np.arange(0, len(imgspaths), 1)
FindNearestNeighbors(25,Allimagesfeatures,queryImgFE,idx1)
# Out:
# Ahmed_Ghazi
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F91F4C4FE10>
#  Similar Images as below
#  ==============================
# similarity images search done in  1.318126916885376  seconds

# %% [markdown]
# **Image search Engine model implementation using PCA( Principal component analysis):**
#
# PCA (Dimensionality deduction) is algorithm used for dimensionality deduction
# •	The pca object stores the actual transformation matrix of all imagesfeatures which was fit in the pca object. We can now use it to transform any original feature vector (of length 4096 colums) into a reduced 700-dimensional feature vector
#
# •	The assumption we can now make is that two images which have similar content, should produce similar feature vectors. we use same query image and compute a measurement of the dissimilarity (or distance) of that image's PCA feature vector to every other image's feature vector. The dissimilarity metric we use is cosine distance.
#
# •	The list similar_idx contains the image's similarity to every other one. We can sort that list and find the indexes of the most similar images. The next cell will sort them, and then find the most similar items, and return the indexes 25 most similar images. Notice we take from indexes 1:26 rather than 0:25 because the most similar image to the query image, will trivially be the query image itself, since it is included in the distance calculation

# %%
from sklearn.decomposition import PCA
from scipy.spatial import distance
starttime=time.time()
pca = PCA(n_components=400)
pca.fit(Allimagesfeatures)
print("Before reducing dimensions - size is",Allimagesfeatures.shape)
pca_Allfeatures = pca.transform(Allimagesfeatures)
print("After reducing dimensions - size is",pca_Allfeatures.shape)

# find distance between query image and all other images
similar_idx = [ distance.cosine(pca_Allfeatures[query_image_idx], feat) for feat in pca_Allfeatures]
print(imglabels[query_image_idx])
display(img1)
#idx_closest = sorted(range(len(similar_idx)), key=lambda k: similar_idx[k])[1:6]
# Extract 25 images that have lowest distance
ids2 = np.argsort(similar_idx)[1:26]
#print(ids2)
scores = [(similar_idx[id],imgspaths[id]) for id in ids2]
axes=[]
fig=plt.figure(figsize=(8,10))
print(" Similar Images \n ==============================")
for j in range(len(scores)):
  score = scores[j]
  axes.append(fig.add_subplot(5, 5, j+1))
  subplot_title=round(score[0],7)
  axes[-1].set_title(subplot_title)  
  plt.axis('off')
  plt.imshow(Image.open(score[1]))
fig.tight_layout()
plt.show()
endtime=time.time()
print("similarity images search using PCA in",(endtime-starttime)," seconds")
# Out:
# Before reducing dimensions - size is (1508, 4096)
# After reducing dimensions - size is (1508, 400)
# Ahmed_Ghazi
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F91F4C4FE10>
#  Similar Images
#  ==============================
# similarity images search using PCA in 3.256476402282715  seconds

# %% [markdown]
# **	Image search Engine model implementation using FaceNet,MTCNN and Keras:**
#
# •	To improve image search engine baseline model, we used FaceNet,MTCNN and sklearn nearest neighbors algorithm.
#
# •	FaceNet is a face recognition system developed in 2015 by researchers at Google that achieved then state-of-the-art results on a range of face recognition benchmark datasets. opensource implementations of the model and pretrained modes are available.
#
# •	The FaceNet system can be used to extract high-quality features from faces, called face embeddings, that can then be used to train a face identification system. This model takes RGB images of 160×160 and generates an embedding of size 128 for an image.
#
#
# •	Multi-task Cascaded Convolutional Networks (MTCNN) is a framework developed as a solution for both face detection and face alignment. The process consists of three stages of convolutional networks that are able to recognize faces and landmark location such as eyes, nose, and mouth.
#
# •	NearestNeighbors algorithm to find nearest neighbors (images)
#
#
# 	Below are implementation steps of image search engine using Facenet,MTCNN and KNN:
#
# •	Upload image dataset
#
# •	Detect all faces from all images using MTCNN.
#
# •	Load query image (we select image randomly)
#
#
# •	Detect all faces from query image
#
# •	Load Facenet pretrained model
#
# •	Extract features from all faces of dataset images using Facenet
#
# •	Extract features from all faces of query image
#
# •	Calculate the similarities of query image with all images using KNN
#
# algorithm. This algorithm calculates distances (Euclidean Distance) between query image features with all images features
#
# •	Retrieve the most similar result:  we get k images that has smaller distances to query image to get similar images

# %% [markdown]
# **	Below are implementation steps of image search engine using python code:**
#
# •	Please install mtcnn and verify installation by getting version number
# Commands:
# Pip install mtcnn
# Import mtcnn
# Print(mtcnn.__version__)

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 5.3 MB/s
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (2.8.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.21.6)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
import mtcnn
# print version
print(mtcnn.__version__)
# Out:
# 0.1.0

# %% [markdown]
# **•	Below is the code to extract faces from a image using MTCNN**

# %%
# function for face detection with mtcnn
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN
# extract a single face from a given photograph
def extract_Imgfaces(filename, label,idx,required_size=(160, 160),data_type = 'train'):
  subimgs_array =list()
  imgfacelabels=list()
  imgfaceindex=list()
  # load image from file
  image = Image.open(filename)
  # convert to RGB, if needed
  image = image.convert('RGB')
	# convert to array
  pixels = asarray(image)
	# create the detector, using default weights
  detector = MTCNN()
	# detect faces in the image
  results = detector.detect_faces(pixels)
  #print(idx," ","results=",len(results) )
  # extract the bounding box from all the faces
  for res in range(len(results)):
      x1, y1, width, height = results[res]['box']
      x1, y1 = abs(x1), abs(y1)
      x2, y2 = x1 + width, y1 + height
	    # extract the face
      face = pixels[y1:y2, x1:x2]
      # resize pixels to the model size
      image = Image.fromarray(face)
      image = image.resize(required_size)
      subimg = asarray(image)
      #print(type(subimg))
      subimgs_array.append(subimg)
      imgfacelabels.append(label)
      imgfaceindex.append(idx)
  if data_type == 'train':
    return subimgs_array,imgfacelabels,imgfaceindex
  else:
    return subimg,imgfacelabels,idx

# %% [markdown]
# **•	Below is the code to extract faces from all images using MTCNN. It took more than 30 minutes from 1508 images**
#
# Note: the code is written to extract all faces from image

# %%
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN
def ExtractAllImgsFaces():
  AllImgsfaces=list()
  AllImgslabels=list()
  AllImgsidx=list()
  #testpath=['/content/sample_data/lfw/AJ_Cook/AJ_Cook_0001.jpg','/content/sample_data/lfw/AJ_Cook/Ainsworth_Dyer/Ainsworth_Dyer_0001.jpg']
  for i in range(len(imgspaths)):
    subimgs,labels,idxlist= extract_Imgfaces(imgspaths[i],imglabels[i],i)
    #print(type(subimgs))
    AllImgsfaces.extend(subimgs)
    AllImgslabels.extend(labels)
    AllImgsidx.extend(idxlist)
    #print(imgspaths[i])
  return asarray(AllImgsfaces),asarray(AllImgslabels),asarray(AllImgsidx)

startttime=time.time()
trainimages,trainlabels,tranidx=ExtractAllImgsFaces()
endtime=time.time()
print("Faces extraction from images is done in",(endtime-starttime)," seconds")

print(trainimages.shape)
print(trainlabels.shape)
print(tranidx)
# Out:
# WARNING:tensorflow:5 out of the last 1512 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f91eff44200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 1518 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f91ece28440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Faces extraction from images is done in 1881.0704629421234  seconds
# (1798, 160, 160, 3)
# (1798,)
# [   0    1    2 ... 1505 1506 1507]

# %% [markdown]
# **Below is the code to extract faces from query images using MTCNN. We save extracted faces array and respective images labels at npz file. It is just avoid faces detection again and again**

# %%
from numpy import savez_compressed
print(trainimages.shape)
print(trainlabels.shape)
testimgs,testlabels,testidx = extract_Imgfaces(imgspaths[query_image_idx],imglabels[query_image_idx],query_image_idx,data_type = 'test')
#print(type(testimgs))
testimgfaces=asarray(testimgs)
testlabels=asarray(testlabels)
print(testimgs.shape)
print(testlabels.shape)
# save arrays to one file in compressed format
savez_compressed('/content/sample_data/faces-dataset.npz', trainimages, trainlabels, testimgs, testlabels)
# Out:
# (1798, 160, 160, 3)
# (1798,)
# (160, 160, 3)
# (1,)

# %% [markdown]
# **•	Below is the code to Load Facenet pretrained model**

# %%
# example of loading the keras facenet model
from keras.models import load_model
# load the model
model = load_model('/content/sample_data/facenet_keras.h5')
# summarize input and output shape
print(model.inputs)
print(model.outputs)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# [<KerasTensor: shape=(None, 160, 160, 3) dtype=float32 (created by layer 'input_1')>]
# [<KerasTensor: shape=(None, 128) dtype=float32 (created by layer 'Bottleneck_BatchNorm')>]

# %% [markdown]
# **•	Below is the code extract features from a face image of full image dataset. It took more than 30 minutes.**
# The features will be 128 array
# Faces array with dimension is 160,160,3 for each face

# %%
def ExtractImg_feature_facenet(model, img):
    # scale pixel values
    img = img.astype('float32')
    # standardization
    mean, std = img.mean(), img.std()
    img = (img-mean)/std
    
    # transform image into multidimentional
    imgsample = np.expand_dims(img, axis=0)
    # make prediction to get embedding
    #print("img",imgsample.shape)
    feature = model.predict(imgsample)[0]
    return feature

# %% [markdown]
# **•	Below is the code save to extracted features,labels of all faces of dataset and query image faces features,labels in npz file  for future use.**

# %%
from numpy import load
# load the face dataset
imgfaces = load('/content/sample_data/faces-dataset.npz',allow_pickle=True)
trainimagesface, traininglabel, testimgsface,testlabelslabel = imgfaces['arr_0'], imgfaces['arr_1'], imgfaces['arr_2'], imgfaces['arr_3']
print('Loaded: ', trainimagesface.shape, traininglabel.shape, testimgsface.shape, testlabelslabel.shape)
# Out:
# Loaded:  (1798, 160, 160, 3) (1798,) (160, 160, 3) (1,)

# %%
Allimgfeatfacenet=[]
for i in range(len(trainimagesface)):
  #print(trainimagesfeat[i].shape)
  embedding = ExtractImg_feature_facenet(model, trainimagesface[i])
  Allimgfeatfacenet.append(embedding)
Allimgfeatfacenet = asarray(Allimgfeatfacenet)
#print(Allimgfeatfacenet.shape)
endtime=time.time()
print("Features extraction using facenet done in",(endtime-starttime)," seconds")
# Out:
# Features extraction using facenet done in 2148.5927176475525  seconds

# %%
queryImgfeatures=ExtractImg_feature_facenet(model, testimgsface)
#queryImgfeatures=np.expand_dims(queryImgfeatures, axis=0)
print(queryImgfeatures.shape)
print((np.expand_dims(queryImgfeatures, axis=0)).shape)
savez_compressed('/content/sample_data/faces-dataset_embeddings.npz', Allimgfeatfacenet, trainlabels, queryImgfeatures, testlabels)
# Out:
# (128,)
# (1, 128)

# %% [markdown]
# **•	We find distance between features(extracted using facenet) to  find similar images using nearest neighbors algorithm. It took 1.3 seconds**

# %%
if len(Allimgfeatfacenet)>0 and len(queryImgfeatures)>0:
  FindNearestNeighbors(25,Allimgfeatfacenet,queryImgfeatures,tranidx)
# Out:
# Ahmed_Ghazi
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F91F4C4FE10>
#  Similar Images as below
#  ==============================
# similarity images search done in  1.3382549285888672  seconds
